# %%
import os
import cv2
import numpy as np
from PIL import Image
from tqdm import tqdm

# %%
def create_color_to_label_map(mask_folder_path, valid_exts=(".png", ".jpg", ".jpeg")):
    """
    Scans all masks in a folder to find unique colors and create a mapping
    from color to a class label.
    """
    print(f"Scanning masks in '{mask_folder_path}'...")

    unique_colors = set()

    # Filter only valid image files
    mask_files = [f for f in os.listdir(mask_folder_path) if f.lower().endswith(valid_exts)]

    if not mask_files:
        raise ValueError(f"No image files found in {mask_folder_path}")

    for filename in tqdm(mask_files, desc="Finding unique colors"):
        mask_path = os.path.join(mask_folder_path, filename)

        # Read image
        mask_bgr = cv2.imread(mask_path)
        if mask_bgr is None:
            print(f"⚠️ Skipping unreadable file: {filename}")
            continue

        mask_rgb = cv2.cvtColor(mask_bgr, cv2.COLOR_BGR2RGB)

        # Reshape to list of pixels
        pixels = mask_rgb.reshape(-1, 3)

        # Get unique RGB colors from this mask
        unique_pixel_colors = np.unique(pixels, axis=0)

        # Add to global set
        for color in unique_pixel_colors:
            unique_colors.add(tuple(color))

    # Sort colors and assign labels
    sorted_colors = sorted(list(unique_colors))
    color_to_label = {color: label for label, color in enumerate(sorted_colors)}

    print("\nScan complete!")
    print(f"Found {len(color_to_label)} unique classes across {len(mask_files)} files.")

    return color_to_label

# %%
mask_path = "dataset/cat_and_dog_dataset/SegmentationClass"
COLOR_TO_LABEL = create_color_to_label_map(mask_path)
COLOR_TO_LABEL
# Out:
# Scanning masks in 'dataset/cat_and_dog_dataset/SegmentationClass'...
# Finding unique colors: 100%|██████████| 297/297 [01:47<00:00,  2.76it/s]
# Scan complete!
# Found 3 unique classes across 297 files.
# {(np.uint8(0), np.uint8(0), np.uint8(0)): 0,
#  (np.uint8(0), np.uint8(128), np.uint8(0)): 1,
#  (np.uint8(128), np.uint8(0), np.uint8(0)): 2}

# %%
import numpy as np
import cv2
from PIL import Image

def encode_mask_to_grayscale(mask_path, color_map):
    """
    Converts an RGB segmentation mask to a grayscale mask with class labels.
    """
    mask_bgr = cv2.imread(mask_path)
    mask_rgb = cv2.cvtColor(mask_bgr, cv2.COLOR_BGR2RGB)
    height, width, _ = mask_rgb.shape
    
    # Create an empty grayscale mask (height x width)
    mask_grayscale = np.zeros((height, width), dtype=np.uint8)
    
    # For each color in our map, find where it is in the mask and assign the label
    for color, label in color_map.items():
        # Find pixels matching the color
        matches = np.where(np.all(mask_rgb == color, axis=-1))
        mask_grayscale[matches] = label
        
    return mask_grayscale

# %%
input_folder = "dataset/cat_and_dog_dataset/SegmentationClass"
output_folder = "dataset/cat_and_dog_dataset/encoded_masks"
os.makedirs(output_folder, exist_ok=True)

# Loop through all mask images
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")):
        mask_path = os.path.join(input_folder, filename)
        
        # Encode to grayscale
        grayscale_label_mask = encode_mask_to_grayscale(mask_path, COLOR_TO_LABEL)
        
        # Save with same filename but as .png (better for masks than jpg)
        save_path = os.path.join(output_folder, os.path.splitext(filename)[0] + ".png")
        cv2.imwrite(save_path, grayscale_label_mask)

        print(f"✅ Saved encoded mask: {save_path}")

print("\nAll masks processed and saved!")
# Out:
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2413.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2386.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2452.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2372.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2439.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.37.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2387.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2437.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.34.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2415.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.44.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2490.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2441.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2410.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2400.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2377.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2447.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.20.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2450.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2368.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2418.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2487.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2459.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2379.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2451.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2382.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2463.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2460.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2496.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2367.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2421.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2488.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2435.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2470.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.26.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2432.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2419.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2381.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2422.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2397.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2499.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2447.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2442.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2367.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2439.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2444.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.12.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.42.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.31.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2493.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2469.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2375.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2378.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2464.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.18.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2397.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.7.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2449.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.33.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2461.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2365.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2436.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.1.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2372.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.45.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2408.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2402.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2373.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2445.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2463.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2417.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2451.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2482.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.46.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2476.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2436.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2364.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2383.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2485.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.29.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2441.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2454.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2390.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2446.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2453.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2429.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2420.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.38.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2457.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2440.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2458.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2473.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2371.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2427.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2423.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2412.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2390.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2392.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2369.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2471.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2395.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2401.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.48.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2391.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2416.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2393.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2369.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2455.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2450.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2409.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2422.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2380.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2458.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2411.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2478.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2448.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2388.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.13.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2395.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2421.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2374.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2399.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2419.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2426.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2448.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2467.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.28.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.30.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2460.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2435.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.19.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2411.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2464.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.39.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2457.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2412.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2431.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2389.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2455.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2376.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2370.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2446.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2406.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.4.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2374.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2385.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2392.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2414.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2468.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2402.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.24.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2375.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2423.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.41.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2381.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2474.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2434.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2380.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2465.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2471.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2399.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2432.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.43.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2424.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2465.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.11.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2415.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2434.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2384.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2370.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2491.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2469.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2406.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2461.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2443.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2472.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2431.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.21.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2400.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2398.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2428.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.6.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2388.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2403.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2477.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2475.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.14.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2483.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2479.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2394.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2433.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2376.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2430.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2428.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2403.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2438.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2404.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.47.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2437.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2389.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.32.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2425.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2401.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2497.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.25.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2409.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2414.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2480.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2462.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2377.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2382.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2467.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2466.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2405.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2360.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2408.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2454.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.49.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2466.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2472.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2420.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2470.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2394.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.5.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2362.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.40.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2410.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2396.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2456.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.15.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2456.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2413.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2396.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.16.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2417.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2438.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.9.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2366.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2361.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2384.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2494.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2424.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2468.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2366.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2430.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2445.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2405.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2489.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2404.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.8.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2371.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.27.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2433.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2442.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2398.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2391.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2368.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2453.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2373.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2486.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2495.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2443.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2379.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2452.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.17.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2407.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2418.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2407.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2498.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2459.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2462.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2440.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.50.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2385.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2393.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2386.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2444.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.22.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2425.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.23.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2429.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2378.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2449.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2484.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2427.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.35.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2492.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2426.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2387.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.10.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2473.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.36.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.2416.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2363.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/dog.2383.png
# ✅ Saved encoded mask: dataset/cat_and_dog_dataset/encoded_masks/cat.3.png
#
# All masks processed and saved!

# %% [markdown]
# ### Reread the encoded mask

# %%
new_grayscale_label_mask = cv2.imread(save_path)
new_grayscale_label_mask = cv2.cvtColor(new_grayscale_label_mask, cv2.COLOR_BGR2GRAY)
plt.imshow(new_grayscale_label_mask)
# Out:
# [ WARN:0@14416.690] global loadsave.cpp:275 findDecoder imread_('dataset/cat_and_dog_dataset/encoded_masks/cat.3.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 2
#       1 new_grayscale_label_mask = cv2.imread(save_path)
# ----> 2 new_grayscale_label_mask = cv2.cvtColor(new_grayscale_label_mask, cv2.COLOR_BGR2GRAY)
#       3 plt.imshow(new_grayscale_label_mask)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
